# %%
import boto3
s3 = boto3.client(
    's3',
    endpoint_url='http://local-s3-service.ezdata-system.svc.cluster.local:30000',
)
s3.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': '141310000005c',
#   'HostId': '141310000005c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'content-type': 'application/xml',
#    'date': 'Thu, 11 Sep 2025 08:23:47 GMT',
#    'server': 'envoy',
#    'strict-transport-security': 'max-age=86400',
#    'x-amz-id-2': '141310000005c',
#    'x-amz-request-id': '141310000005c',
#    'x-content-type-options': 'nosniff',
#    'x-frame-options': 'SAMEORIGIN',
#    'x-envoy-upstream-service-time': '431',
#    'transfer-encoding': 'chunked'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'mlflow.sg2pcai172',
#    'CreationDate': datetime.datetime(2025, 9, 4, 19, 18, 11, tzinfo=tzlocal())}],
#  'Owner': {'DisplayName': 's3user', 'ID': '103'}}

# %%
import boto3

# Initialize S3 client
s3 = boto3.client('s3', endpoint_url='http://local-s3-service.ezdata-system.svc.cluster.local:30000')

# Create new bucket
#s3.create_bucket(Bucket='rundmc')

# Upload the bento file
s3.upload_file('annote_v3.bento', 'rundmc', 'annote_v3.bento')

# Verify upload
response = s3.list_objects_v2(Bucket='rundmc')
print("Files in rundmc bucket:", response.get('Contents', []))
# Out:
# Files in rundmc bucket: [{'Key': 'annote.bento', 'LastModified': datetime.datetime(2025, 11, 14, 12, 50, 23, 259060, tzinfo=tzlocal()), 'ETag': '"8747cffea243df60fbfd2d473260cdd6"', 'Size': 6732, 'StorageClass': 'STANDARD'}, {'Key': 'annote_v2.bento', 'LastModified': datetime.datetime(2025, 11, 14, 13, 15, 49, 732697, tzinfo=tzlocal()), 'ETag': '"16178884f79b303274a33b00df7c326e"', 'Size': 6720, 'StorageClass': 'STANDARD'}, {'Key': 'annote_v3.bento', 'LastModified': datetime.datetime(2025, 11, 14, 13, 36, 46, 336351, tzinfo=tzlocal()), 'ETag': '"ae1fd583c77ff3981d85eb471dbf89bb"', 'Size': 6732, 'StorageClass': 'STANDARD'}, {'Key': 'cbox.bento', 'LastModified': datetime.datetime(2025, 9, 22, 22, 58, 57, 546830, tzinfo=tzlocal()), 'ETag': '"cececc77edbea154d542ccd3e8e21d01"', 'Size': 139788, 'StorageClass': 'STANDARD'}, {'Key': 'nllb-gpu-v2.bento', 'LastModified': datetime.datetime(2025, 9, 11, 10, 24, 42, 614415, tzinfo=tzlocal()), 'ETag': '"68eaca8d20cab12ba9cd49bd7b3aec55"', 'Size': 7960, 'StorageClass': 'STANDARD'}, {'Key': 'nllb-gpu-v3.bento', 'LastModified': datetime.datetime(2025, 9, 11, 11, 14, 16, 126317, tzinfo=tzlocal()), 'ETag': '"0ae1026182c791c0962e9de4ef96518c"', 'Size': 8112, 'StorageClass': 'STANDARD'}, {'Key': 'nllb-gpu-v4.bento', 'LastModified': datetime.datetime(2025, 9, 11, 12, 37, 10, 632750, tzinfo=tzlocal()), 'ETag': '"5ed62cfe88f6d090ac004afafc5fab12"', 'Size': 8752, 'StorageClass': 'STANDARD'}, {'Key': 'nllb-gpu.bento', 'LastModified': datetime.datetime(2025, 9, 11, 10, 7, 49, 549584, tzinfo=tzlocal()), 'ETag': '"4a43a2033a465e7ef1a7c5a55b854347"', 'Size': 7956, 'StorageClass': 'STANDARD'}, {'Key': 'nllb-v2.bento', 'LastModified': datetime.datetime(2025, 9, 11, 8, 40, 39, 303331, tzinfo=tzlocal()), 'ETag': '"f4bdd4ab539cf591c34620f57de908da"', 'Size': 7168, 'StorageClass': 'STANDARD'}, {'Key': 'nllb-v3.bento', 'LastModified': datetime.datetime(2025, 9, 11, 9, 5, 55, 277724, tzinfo=tzlocal()), 'ETag': '"810a818cb86e28417ef7574e8c3e639e"', 'Size': 7352, 'StorageClass': 'STANDARD'}, {'Key': 'nllb-v4.bento', 'LastModified': datetime.datetime(2025, 9, 11, 9, 51, 30, 618315, tzinfo=tzlocal()), 'ETag': '"c01b7b7dee1d76829b6833258430556f"', 'Size': 7388, 'StorageClass': 'STANDARD'}, {'Key': 'nllb.bento', 'LastModified': datetime.datetime(2025, 9, 11, 8, 25, 2, 732480, tzinfo=tzlocal()), 'ETag': '"919805cbeaa5a6b0ee0a8aaf94357561"', 'Size': 7164, 'StorageClass': 'STANDARD'}, {'Key': 'nllb_mlis.bento', 'LastModified': datetime.datetime(2025, 9, 11, 13, 15, 30, 343774, tzinfo=tzlocal()), 'ETag': '"b297ec3f3622520a1b156ec40c68efd3"', 'Size': 8232, 'StorageClass': 'STANDARD'}, {'Key': 'pyannote.bento', 'LastModified': datetime.datetime(2025, 9, 11, 16, 43, 57, 75167, tzinfo=tzlocal()), 'ETag': '"b67817b0b768477437c8134d7e6eaf9c"', 'Size': 6724, 'StorageClass': 'STANDARD'}, {'Key': 'pyannote_v2.bento', 'LastModified': datetime.datetime(2025, 11, 14, 10, 58, 45, 554088, tzinfo=tzlocal()), 'ETag': '"2efc3d46ef8bdd56f525bd280b8c7978"', 'Size': 6720, 'StorageClass': 'STANDARD'}, {'Key': 'pyannote_v3.bento', 'LastModified': datetime.datetime(2025, 11, 14, 11, 18, 3, 590229, tzinfo=tzlocal()), 'ETag': '"c843472757e07f574f7010e0cff340be"', 'Size': 6732, 'StorageClass': 'STANDARD'}, {'Key': 'pyannote_v4.bento', 'LastModified': datetime.datetime(2025, 11, 14, 11, 36, 54, 869156, tzinfo=tzlocal()), 'ETag': '"9c6e02151fdd9fed7707e0d20faebeaf"', 'Size': 6740, 'StorageClass': 'STANDARD'}, {'Key': 'pyannote_v5.bento', 'LastModified': datetime.datetime(2025, 11, 14, 11, 47, 11, 255381, tzinfo=tzlocal()), 'ETag': '"0a8936cd3c0b590cc87f4b700396b9bb"', 'Size': 6740, 'StorageClass': 'STANDARD'}, {'Key': 'pyannote_v6.bento', 'LastModified': datetime.datetime(2025, 11, 14, 12, 0, 12, 607510, tzinfo=tzlocal()), 'ETag': '"0ad4db1bd9834ff806ee5ae649d8af4e"', 'Size': 6740, 'StorageClass': 'STANDARD'}, {'Key': 'whisper.bento', 'LastModified': datetime.datetime(2025, 9, 11, 18, 23, 1, 548066, tzinfo=tzlocal()), 'ETag': '"f667443546794f2c0d07ae ...

# %%
creds = boto3.Session().get_credentials()
print(f"Access Key: {creds.access_key}")
print(f"Secret Key: {creds.secret_key}")
print(f"Token: {creds.token}")
# Out:
# Access Key: eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICI3ZTVVQ0l1TTVvd3k3cHBBbjlOZWtKdlI1dEVkMXR5SjJwX1E1aVJuaG1BIn0.....H9M4sDngkJaJBvivAPp7q0BJwN0j0ZYibKDp3Fh4wJ2HB6KpXAZ2QgGC0tnaI5BUuI4u7nGW9ot8shUTxzWurS5pAFAxmgBYEoQmlcL9Mu9oSdZH-7OTJt2UXKFBKT0Y_eNM1QTHDc6PBkMJbwQlwtteGY-wO3PEAuJabQHOygeYUNrxwA9VS5wp_x8_LiVN_JhsrBMvBlVeg5EdlrLbRO9Vfmf-sgpruUs55CwVplmYeyEh1Y4OsRWqESySKunv4ekDEzFJsPywD2mAJ3_sEo104x7BYeW9L8CpAx2kk38Lf1Ild5iPqQwUQuYqKMEBMjnw48dYjVUWp4pBlA6B9w
# Secret Key: s3
# Token:
