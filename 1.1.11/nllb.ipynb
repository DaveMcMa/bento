# %%
import requests
import json

# Configuration
url = "https://nllb-gpu-predictor-david-mcmahon3-84f246c0.ingress.pcai0308.sg2.hpecolo.net/translate"
token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3NTc1ODY5MDMsImlzcyI6ImFpb2xpQGhwZS5jb20iLCJzdWIiOiI2ODI4NzlhNy0xZjM0LTQwZjUtYWJiYS0yYjY1OWU5Zjg5ZmEiLCJ1c2VyIjoiZGF2aWQubWNtYWhvbjMifQ.V1GC5WV95_n9KfvNjIHP4eJMq67qp8fz8QQlKJ_aQujEXU5oKozoTguQMErrysIKEqqAJN4LLsQXfmv_GBgJ8tgTshAlsLlWWRWthD2tztlQ2DBX8VgRFuSW6iL5VGJ6-FfBFT77ZOqSf_AnqsxJLIU5JCDpRs3EeQq0xhBOoDuzWLB-lA9YJUWkZdMfgGB_-vDC-TRqC6OdqwBS7qqKVZCghsw7ofbclVu3eatm_a2QG3kFNwKyu4sfScTizsskL-WGqrkjRTahrLvdk9P3NJ-bKB623vP6WBFn9dTxTn3mnWUatoIJRnT2uCRtaFlpRMYfZzJy0nC6kbS4O4yDSg"

# Headers
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {token}"
}

# Polish text to translate
data = {
    "text": "Cześć, jak się masz?",
    "source_lang": "pol_Latn",
    "target_lang": "eng_Latn"
}

# Make the request
response = requests.post(url, headers=headers, json=data)

# Print the result
if response.status_code == 200:
    result = response.json()
    print(f"Original (Polish): {result['source_text']}")
    print(f"Translation (English): {result['translated_text']}")
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 27
#      25 if response.status_code == 200:
#      26     result = response.json()
# ---> 27     print(f"Original (Polish): {result['source_text']}")
#      28     print(f"Translation (English): {result['translated_text']}")
#      29 else:
#
# KeyError: 'source_text'

# %%
import requests
import json

# Configuration
base_url = "https://nllb-gpu-predictor-david-mcmahon3-84f246c0.ingress.pcai0308.sg2.hpecolo.net"
token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3NTc1ODY5MDMsImlzcyI6ImFpb2xpQGhwZS5jb20iLCJzdWIiOiI2ODI4NzlhNy0xZjM0LTQwZjUtYWJiYS0yYjY1OWU5Zjg5ZmEiLCJ1c2VyIjoiZGF2aWQubWNtYWhvbjMifQ.V1GC5WV95_n9KfvNjIHP4eJMq67qp8fz8QQlKJ_aQujEXU5oKozoTguQMErrysIKEqqAJN4LLsQXfmv_GBgJ8tgTshAlsLlWWRWthD2tztlQ2DBX8VgRFuSW6iL5VGJ6-FfBFT77ZOqSf_AnqsxJLIU5JCDpRs3EeQq0xhBOoDuzWLB-lA9YJUWkZdMfgGB_-vDC-TRqC6OdqwBS7qqKVZCghsw7ofbclVu3eatm_a2QG3kFNwKyu4sfScTizsskL-WGqrkjRTahrLvdk9P3NJ-bKB623vP6WBFn9dTxTn3mnWUatoIJRnT2uCRtaFlpRMYfZzJy0nC6kbS4O4yDSg"

# Headers
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {token}"
}

def test_endpoint(endpoint_name, url, data):
    print(f"\n{'='*60}")
    print(f"TESTING: {endpoint_name}")
    print(f"URL: {url}")
    print(f"REQUEST DATA:")
    print(json.dumps(data, indent=2, ensure_ascii=False))
    print(f"{'='*60}")
    
    try:
        response = requests.post(url, headers=headers, json=data)
        
        print(f"RESPONSE STATUS: {response.status_code}")
        print(f"RESPONSE HEADERS: {dict(response.headers)}")
        print(f"RESPONSE TEXT: {response.text}")
        
        if response.status_code == 200:
            try:
                result = response.json()
                print(f"RESPONSE JSON:")
                print(json.dumps(result, indent=2, ensure_ascii=False))
                return result
            except json.JSONDecodeError as e:
                print(f"JSON DECODE ERROR: {e}")
                return None
        else:
            print(f"ERROR RESPONSE - Status: {response.status_code}")
            try:
                error_json = response.json()
                print(f"ERROR JSON:")
                print(json.dumps(error_json, indent=2, ensure_ascii=False))
            except:
                print("Could not parse error response as JSON")
            return None
            
    except Exception as e:
        print(f"REQUEST EXCEPTION: {e}")
        return None

# Test 1: Basic translation (Polish to English)
test1_data = {
    "text": "Cześć, jak się masz?",
    "source_lang": "pol_Latn",
    "target_lang": "eng_Latn"
}
test_endpoint("Basic Translation (Polish to English)", f"{base_url}/translate", test1_data)

# Test 2: Translation with all parameters
test2_data = {
    "text": "Dzień dobry, miło Cię poznać!",
    "source_lang": "pol_Latn",
    "target_lang": "eng_Latn",
    "max_length": 256,
    "num_beams": 2,
    "length_penalty": 0.8
}
test_endpoint("Translation with Parameters", f"{base_url}/translate", test2_data)

# Test 3: English to Polish
test3_data = {
    "text": "Hello, how are you doing today?",
    "source_lang": "eng_Latn",
    "target_lang": "pol_Latn"
}
test_endpoint("English to Polish", f"{base_url}/translate", test3_data)

# Test 4: Batch translation (if endpoint exists)
test4_data = {
    "texts": [
        "Hello world",
        "Good morning",
        "Thank you very much"
    ],
    "source_lang": "eng_Latn",
    "target_lang": "pol_Latn"
}
test_endpoint("Batch Translation", f"{base_url}/translate_batch", test4_data)

# Test 5: Get supported languages
test5_data = {}
test_endpoint("Get Supported Languages", f"{base_url}/get_languages", test5_data)

# Test 6: Health check
test6_data = {}
test_endpoint("Health Check", f"{base_url}/health", test6_data)

# Test 7: Error case - empty text
test7_data = {
    "text": "",
    "source_lang": "pol_Latn",
    "target_lang": "eng_Latn"
}
test_endpoint("Error Case - Empty Text", f"{base_url}/translate", test7_data)

# Test 8: Error case - invalid language code
test8_data = {
    "text": "Test text",
    "source_lang": "invalid_lang",
    "target_lang": "eng_Latn"
}
test_endpoint("Error Case - Invalid Language", f"{base_url}/translate", test8_data)

print(f"\n{'='*60}")
print("ALL TESTS COMPLETED")
print(f"{'='*60}")
# Out:
# ...
# TESTING: Basic Translation (Polish to English)
# URL: https://nllb-gpu-predictor-david-mcmahon3-84f246c0.ingress.pcai0308.sg2.hpecolo.net/translate
# REQUEST DATA:
# {
#   "text": "Cześć, jak się masz?",
#   "source_lang": "pol_Latn",
#   "target_lang": "eng_Latn"
# }
# ...
# RESPONSE STATUS: 200
# RESPONSE HEADERS: {'content-length': '143', 'content-type': 'application/json', 'date': 'Thu, 11 Sep 2025 10:41:27 GMT', 'server': 'istio-envoy', 'x-bentoml-request-id': '1034971704507198538', 'x-envoy-upstream-service-time': '9269'}
# RESPONSE TEXT: {"source_text":"Cześć, jak się masz?","translated_text":"Hi, how are you?","source_lang":"pol_Latn","target_lang":"eng_Latn","success":true}
# RESPONSE JSON:
# {
#   "source_text": "Cześć, jak się masz?",
#   "translated_text": "Hi, how are you?",
#   "source_lang": "pol_Latn",
#   "target_lang": "eng_Latn",
#   "success": true
# }
#
# ...
# TESTING: Translation with Parameters
# ...
